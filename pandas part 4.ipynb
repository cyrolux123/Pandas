# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.drop('PassengerId',axis = 1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#permanently delete the column
#df.drop('PassengerId',axis = 1,inplace = True)
#df.drop(3,inplace = True)

# %%
df.set_index('Name')
#permanently set the index
#df.set_index('Name',inplace = True)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.reset_index()
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        1            2         1       1
# 2        2            3         1       3
# 3        3            4         1       1
# 4        4            5         0       3
# ..     ...          ...       ...     ...
# 886    886          887         0       2
# 887    887          888         1       1
# 888    888          889         0       3
# 889    889          890         1       1
# 890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
d = {
    'key1' : [3,4,5,6,7],
    'key2' : [7,8,9,10,6],
    'key3' : [11,12,13,14,15]
}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     3     7    11
# 1     4     8    12
# 2     5     9    13
# 3     6    10    14
# 4     7     6    15

# %%
df1 = pd.read_csv('people.csv')

# %%
df1
# Out:
#     Name        Year Income   Education  Graduation    Standing
# 0  Alice        1980     2M   Harvard U    20200312     Medium.
# 1   Rumy  1978[1077]    40K      Oxford    20200414       Low
# 2  Jonny   1982-1985   120K  Oxford Uni    20200801  Excellant+
# 3  Romeo        1992    10M  __Stanford    20200518        low.
# 4   Lily        1987     6M    Harvard/    20210510   Excellant
# 5  Alice        1980     2M   Harvard U    20200312     Medium.
# 6   Rumy  1978[1077]    40K      Oxford    20200414       Low2

# %%
df1.dropna() #temporary delete the nan
#no available any nan so not deleted
#df1.dropna(inplace = True) (permanently delete the nan)
# Out:
#     Name        Year Income   Education  Graduation    Standing
# 0  Alice        1980     2M   Harvard U    20200312     Medium.
# 1   Rumy  1978[1077]    40K      Oxford    20200414       Low
# 2  Jonny   1982-1985   120K  Oxford Uni    20200801  Excellant+
# 3  Romeo        1992    10M  __Stanford    20200518        low.
# 4   Lily        1987     6M    Harvard/    20210510   Excellant
# 5  Alice        1980     2M   Harvard U    20200312     Medium.
# 6   Rumy  1978[1077]    40K      Oxford    20200414       Low2

# %%
df1.dropna(axis = 1) #temporary delete the nan
# Out:
#     Name        Year Income   Education  Graduation    Standing
# 0  Alice        1980     2M   Harvard U    20200312     Medium.
# 1   Rumy  1978[1077]    40K      Oxford    20200414       Low
# 2  Jonny   1982-1985   120K  Oxford Uni    20200801  Excellant+
# 3  Romeo        1992    10M  __Stanford    20200518        low.
# 4   Lily        1987     6M    Harvard/    20210510   Excellant
# 5  Alice        1980     2M   Harvard U    20200312     Medium.
# 6   Rumy  1978[1077]    40K      Oxford    20200414       Low2

# %%
df2 = pd.read_csv('phone.csv')

# %%
df2
# Out:
#      index            date  duration  item    month   network network_type
# 0        0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1        1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2        2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3        3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4        4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile
# ..     ...             ...       ...   ...      ...       ...          ...
# 825    825  13/03/15 00:38     1.000   sms  2015-03     world        world
# 826    826  13/03/15 00:39     1.000   sms  2015-03  Vodafone       mobile
# 827    827  13/03/15 06:58    34.429  data  2015-03      data         data
# 828    828  14/03/15 00:13     1.000   sms  2015-03     world        world
# 829    829  14/03/15 00:16     1.000   sms  2015-03     world        world
#
# [830 rows x 7 columns]

# %%
df2.dropna() #temporary delete the nan
# Out:
#      index            date  duration  item    month   network network_type
# 0        0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1        1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2        2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3        3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4        4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile
# ..     ...             ...       ...   ...      ...       ...          ...
# 825    825  13/03/15 00:38     1.000   sms  2015-03     world        world
# 826    826  13/03/15 00:39     1.000   sms  2015-03  Vodafone       mobile
# 827    827  13/03/15 06:58    34.429  data  2015-03      data         data
# 828    828  14/03/15 00:13     1.000   sms  2015-03     world        world
# 829    829  14/03/15 00:16     1.000   sms  2015-03     world        world
#
# [830 rows x 7 columns]

# %%
df2.fillna('Nabin') #temporary fill the nan
# Out:
#      index            date  duration  item    month   network network_type
# 0        0  15/10/14 06:58    34.429  data  2014-11      data         data
# 1        1  15/10/14 06:58    13.000  call  2014-11  Vodafone       mobile
# 2        2  15/10/14 14:46    23.000  call  2014-11    Meteor       mobile
# 3        3  15/10/14 14:48     4.000  call  2014-11     Tesco       mobile
# 4        4  15/10/14 17:27     4.000  call  2014-11     Tesco       mobile
# ..     ...             ...       ...   ...      ...       ...          ...
# 825    825  13/03/15 00:38     1.000   sms  2015-03     world        world
# 826    826  13/03/15 00:39     1.000   sms  2015-03  Vodafone       mobile
# 827    827  13/03/15 06:58    34.429  data  2015-03      data         data
# 828    828  14/03/15 00:13     1.000   sms  2015-03     world        world
# 829    829  14/03/15 00:16     1.000   sms  2015-03     world        world
#
# [830 rows x 7 columns]

# %%
df
# Out:
#      level_0  index  PassengerId  Survived  Pclass  \
# 0          0      0            1         0       3
# 1          1      1            2         1       1
# 2          2      2            3         1       3
# 3          3      3            4         1       1
# 4          4      4            5         0       3
# ..       ...    ...          ...       ...     ...
# 886      886    886          887         0       2
# 887      887    887          888         1       1
# 888      888    888          889         0       3
# 889      889    889          890         1       1
# 890      890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
df.groupby('Survived')

# %%
g

# %%
g.sum()
# Out:
#            index  PassengerId  Pclass  \
# Survived
# 0         244863       245412    1390
# 1         151632       151974     667
#
#                                                        Name  \
# Survived
# 0         Braund, Mr. Owen HarrisAllen, Mr. William Henr...
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...
#
#                                                         Sex       Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalemalefemalemalefemalema...  12985.50    304
# 1         femalefemalefemalefemalefemalefemalefemalefema...   8219.67    162
#
#           Parch                                             Ticket  \
# Survived
# 0           181  A/5 2117137345033087717463349909A/5. 215134708...
# 1           159  PC 17599STON/O2. 3101282113803347742237736PP 9...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12142.7199  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# ...

# %%
g1 = df.groupby('Pclass')

# %%
g1

# %%
g1.sum()
# Out:
#         level_0   index  PassengerId  Survived  \
# Pclass
# 1         99489   99489        99705       136
# 2         81872   81872        82056        87
# 3        215134  215134       215625       119
#
#                                                      Name  \
# Pclass
# 1       Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       Nasser, Mrs. Nicholas (Adele Achem)Hewlett, Mr...
# 3       Braund, Mr. Owen HarrisHeikkinen, Miss. LainaA...
#
#                                                       Sex      Age  SibSp  \
# Pclass
# 1       femalefemalemalefemalemalemalemalefemalemalema...  7111.42     90
# 2       femalefemalemalemalemalemalefemalefemalefemale...  5168.83     74
# 3       malefemalemalemalemalefemalefemalemalemalefema...  8924.92    302
#
#         Parch                                             Ticket        Fare  \
# Pclass
# 1          77  PC 175991138031746311378311378819950PC 17601PC...  18177.4125
# ...

# %%
df
# Out:
#      level_0  index  PassengerId  Survived  Pclass  \
# 0          0      0            1         0       3
# 1          1      1            2         1       1
# 2          2      2            3         1       3
# 3          3      3            4         1       1
# 4          4      4            5         0       3
# ..       ...    ...          ...       ...     ...
# 886      886    886          887         0       2
# 887      887    887          888         1       1
# 888      888    888          889         0       3
# 889      889    889          890         1       1
# 890      890    890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
df5 = df[['Name','Survived','Pclass']][0:5]

# %%
df6 = df[['Name','Survived','Pclass']][5:10]

# %%
df5
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3

# %%
df6
# Out:
#                                                 Name  Survived  Pclass
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
pd.concat([df5,df6])
# Out:
#                                                 Name  Survived  Pclass
# 0                            Braund, Mr. Owen Harris         0       3
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...         1       1
# 2                             Heikkinen, Miss. Laina         1       3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)         1       1
# 4                           Allen, Mr. William Henry         0       3
# 5                                   Moran, Mr. James         0       3
# 6                            McCarthy, Mr. Timothy J         0       1
# 7                     Palsson, Master. Gosta Leonard         0       3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)         1       3
# 9                Nasser, Mrs. Nicholas (Adele Achem)         1       2

# %%
df7 = pd.concat([df5,df6], axis = 1)

# %%
df7.fillna('Nabin')
# Out:
#                                                 Name Survived Pclass  \
# 0                            Braund, Mr. Owen Harris      0.0    3.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1.0    1.0
# 2                             Heikkinen, Miss. Laina      1.0    3.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1.0    1.0
# 4                           Allen, Mr. William Henry      0.0    3.0
# 5                                              Nabin    Nabin  Nabin
# 6                                              Nabin    Nabin  Nabin
# 7                                              Nabin    Nabin  Nabin
# 8                                              Nabin    Nabin  Nabin
# 9                                              Nabin    Nabin  Nabin
#
#                                                 Name Survived Pclass
# 0                                              Nabin    Nabin  Nabin
# 1                                              Nabin    Nabin  Nabin
# ...

# %%
data1 = pd.DataFrame(
    {
        'key1' : [3,4,5,6,7],
        'key2' : [7,8,9,10,6],
        'key3' : [11,12,13,14,15]
    }
)

# %%
data1
# Out:
#    key1  key2  key3
# 0     3     7    11
# 1     4     8    12
# 2     5     9    13
# 3     6    10    14
# 4     7     6    15

# %%
data2 = pd.DataFrame(
    {
        'key1' : [55,4,5,6,7],
        'key4' : [7,85,9,10,6],
        'key5' : [13,12,13,14,15]
    }
)

# %%
data1
# Out:
#    key1  key2  key3
# 0     3     7    11
# 1     4     8    12
# 2     5     9    13
# 3     6    10    14
# 4     7     6    15

# %%
data2
# Out:
#    key1  key4  key5
# 0    55     7    13
# 1     4    85    12
# 2     5     9    13
# 3     6    10    14
# 4     7     6    15

# %%
pd.merge(data1,data2)
# Out:
#    key1  key2  key3  key4  key5
# 0     4     8    12    85    12
# 1     5     9    13     9    13
# 2     6    10    14    10    14
# 3     7     6    15     6    15

# %%
pd.merge(data1,data2,how = 'left')
# Out:
#    key1  key2  key3  key4  key5
# 0     3     7    11   NaN   NaN
# 1     4     8    12  85.0  12.0
# 2     5     9    13   9.0  13.0
# 3     6    10    14  10.0  14.0
# 4     7     6    15   6.0  15.0

# %%
pd.merge(data1,data2,how = 'right')
# Out:
#    key1  key2  key3  key4  key5
# 0    55   NaN   NaN     7    13
# 1     4   8.0  12.0    85    12
# 2     5   9.0  13.0     9    13
# 3     6  10.0  14.0    10    14
# 4     7   6.0  15.0     6    15

# %%
pd.merge(data1,data2,how = 'outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     3   7.0  11.0   NaN   NaN
# 1     4   8.0  12.0  85.0  12.0
# 2     5   9.0  13.0   9.0  13.0
# 3     6  10.0  14.0  10.0  14.0
# 4     7   6.0  15.0   6.0  15.0
# 5    55   NaN   NaN   7.0  13.0

# %%
pd.merge(data1,data2,how = 'cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        3     7    11      55     7    13
# 1        3     7    11       4    85    12
# 2        3     7    11       5     9    13
# 3        3     7    11       6    10    14
# 4        3     7    11       7     6    15
# 5        4     8    12      55     7    13
# 6        4     8    12       4    85    12
# 7        4     8    12       5     9    13
# 8        4     8    12       6    10    14
# 9        4     8    12       7     6    15
# 10       5     9    13      55     7    13
# 11       5     9    13       4    85    12
# 12       5     9    13       5     9    13
# 13       5     9    13       6    10    14
# 14       5     9    13       7     6    15
# 15       6    10    14      55     7    13
# 16       6    10    14       4    85    12
# 17       6    10    14       5     9    13
# 18       6    10    14       6    10    14
# 19       6    10    14       7     6    15
# 20       7     6    15      55     7    13
# ...

# %%
pd.merge(data1,data2,how = 'outer', on = 'key1')
# Out:
#    key1  key2  key3  key4  key5
# 0     3   7.0  11.0   NaN   NaN
# 1     4   8.0  12.0  85.0  12.0
# 2     5   9.0  13.0   9.0  13.0
# 3     6  10.0  14.0  10.0  14.0
# 4     7   6.0  15.0   6.0  15.0
# 5    55   NaN   NaN   7.0  13.0

# %%
data1 = pd.DataFrame(
    {
        'key1' : [3,4,5,6,7],
        'key2' : [7,8,9,10,6],
        'key3' : [11,12,13,14,15]
    },
    index = ['a','b','c','d','e']
)

# %%
data2 = pd.DataFrame(
    {
        'key11' : [3,4,5,6,7],
        'key22' : [7,8,9,10,6],
        'key33' : [11,12,13,14,15]
    },
    index = ['e','f','g','h','i']
)

# %%
data1
# Out:
#    key1  key2  key3
# a     3     7    11
# b     4     8    12
# c     5     9    13
# d     6    10    14
# e     7     6    15

# %%
data2
# Out:
#    key1  key2  key3
# e     3     7    11
# f     4     8    12
# g     5     9    13
# h     6    10    14
# i     7     6    15

# %%
data1.join(data2)
# Out:
#    key1  key2  key3  key11  key22  key33
# a     3     7    11    NaN    NaN    NaN
# b     4     8    12    NaN    NaN    NaN
# c     5     9    13    NaN    NaN    NaN
# d     6    10    14    NaN    NaN    NaN
# e     7     6    15    3.0    7.0   11.0

# %%
data1.join(data2,how = 'right')
# Out:
#    key1  key2  key3  key11  key22  key33
# e   7.0   6.0  15.0      3      7     11
# f   NaN   NaN   NaN      4      8     12
# g   NaN   NaN   NaN      5      9     13
# h   NaN   NaN   NaN      6     10     14
# i   NaN   NaN   NaN      7      6     15

# %%
data1.join(data2,how = 'inner')
# Out:
#    key1  key2  key3  key11  key22  key33
# e     7     6    15      3      7     11

# %%
data1.join(data2,how = 'outer')
# Out:
#    key1  key2  key3  key11  key22  key33
# a   3.0   7.0  11.0    NaN    NaN    NaN
# b   4.0   8.0  12.0    NaN    NaN    NaN
# c   5.0   9.0  13.0    NaN    NaN    NaN
# d   6.0  10.0  14.0    NaN    NaN    NaN
# e   7.0   6.0  15.0    3.0    7.0   11.0
# f   NaN   NaN   NaN    4.0    8.0   12.0
# g   NaN   NaN   NaN    5.0    9.0   13.0
# h   NaN   NaN   NaN    6.0   10.0   14.0
# i   NaN   NaN   NaN    7.0    6.0   15.0

# %%
data1.join(data2,how = 'cross')
# Out:
#     key1  key2  key3  key11  key22  key33
# 0      3     7    11      3      7     11
# 1      3     7    11      4      8     12
# 2      3     7    11      5      9     13
# 3      3     7    11      6     10     14
# 4      3     7    11      7      6     15
# 5      4     8    12      3      7     11
# 6      4     8    12      4      8     12
# 7      4     8    12      5      9     13
# 8      4     8    12      6     10     14
# 9      4     8    12      7      6     15
# 10     5     9    13      3      7     11
# 11     5     9    13      4      8     12
# 12     5     9    13      5      9     13
# 13     5     9    13      6     10     14
# 14     5     9    13      7      6     15
# 15     6    10    14      3      7     11
# 16     6    10    14      4      8     12
# 17     6    10    14      5      9     13
# 18     6    10    14      6     10     14
# 19     6    10    14      7      6     15
# 20     7     6    15      3      7     11
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare_NPR'] = df['Fare'].apply(lambda x : x * 150)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Fare_INR   Fare_NPR
# 0      0         A/5 21171   7.2500   NaN        S   543.7500   1087.500
# 1      0          PC 17599  71.2833   C85        C  5346.2475  10692.495
# 2      0  STON/O2. 3101282   7.9250   NaN        S   594.3750   1188.750
# ...

# %%
df['Name_Length'] = df['Name'].apply(len)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Fare_INR   Fare_NPR  \
# 0      0         A/5 21171   7.2500   NaN        S   543.7500   1087.500
# 1      0          PC 17599  71.2833   C85        C  5346.2475  10692.495
# 2      0  STON/O2. 3101282   7.9250   NaN        S   594.3750   1188.750
# ...

# %%
def cat_fare(x):
    if x < 10:
        return 'Cheap'
    elif x>=10 and x<20:
        return 'Moderate'
    else:
        return 'Expensive'

# %%
df['Fare_Category'] = df['Fare'].apply(cat_fare)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
